# %%
# import necessary libraries
import warnings
warnings.filterwarnings("ignore")
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle
import h5py

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers.legacy import SGD
import random
from keras.models import load_model

# create an object of WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# importing the GL Bot corpus file for pre-processing

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open("data.json").read()
intents = json.loads(data_file)

# %%
# preprocessing the json data
# tokenization
#nltk.download('punkt')
#nltk.download('wordnet')
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))

# documents = combination between patterns and intents
print (len(documents), "documents")

# classes = intents
print (len(classes), "classes", classes)

# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

# creating a pickle file to store the Python objects which we will use while predicting
pickle.dump(words,open('texts.pkl','wb')) 
pickle.dump(classes,open('labels.pkl','wb'))
# Out:
# 250 documents
# 102 classes ['acceleration_problem', 'accessory_issue', 'battery_lifespan', 'battery_problem', 'body_damage', 'body_paint_issue', 'brake_check', 'brake_fluid', 'brake_issue', 'cable_check', 'carburator_issue', 'chain_drive_maintenance', 'chain_issue', 'chain_lubrication', 'chain_tension', 'check_bearings', 'club_membership', 'clutch_adjustment', 'clutch_cable_issue', 'clutch_issue', 'common_maintenance_errors', 'cooling_fluid', 'cooling_system', 'emergency_kit', 'emergency_scenario', 'emergency_setup', 'engine_noises', 'engine_problem', 'exhaust_check', 'exhaust_issue', 'first_aid_knowledge', 'flashlight_check', 'flooded_engine', 'fork_oil_change', 'fuel_conserving_tips', 'fuel_filter_issue', 'fuel_leak', 'fuel_quality', 'fuel_system_cleaning', 'fuel_tank_check', 'fuel_time_check', 'fuel_warning', 'fuel_warning_light', 'gasoline_quality', 'generic_help', 'greeting', 'handgrip_issue', 'headlight_issue', 'horn_issue', 'idle_issue', 'idling_issue', 'insurance_claim', 'insurance_knowledge', 'lighting_issue', 'long_term_storage', 'long_trip_preparation', 'lost_key_service', 'maintenance_schedule', 'market_trends', 'motor_storage', 'night_riding_tips', 'noanswer', 'noise_issue', 'oil_change', 'oil_leak', 'overheating', 'parking_issue', 'piston_issue', 'radio_issue', 'read_dashboard_light', 'rim_damage', 'road_conditions', 'road_noise', 'road_trip_planning', 'saddle_issue', 'safety_check', 'safety_gear', 'safety_recall', 'seasonal_maintenance', 'seat_adjustment', 'service_frequency', 'signal_light', 'spare_parts', 'spark_plug_issue', 'spark_plug_replacement', 'stand_issue', 'starting_issue', 'suspension_issue', 'thank_you', 'tire_issue', 'tire_pressure', 'tire_replacement', 'tire_rotation', 'transmission_issue', 'trip_planning', 'unexpected_services', 'vibration', 'warn_lights', 'weather_effect', 'windshield_issues', 'winter_bike_storage', 'winter_storage']
# 324 unique lemmatized words [',', 'ada', 'aki', 'akselerasi', 'aksesori', 'aman', 'aneh', 'angin', 'apa', 'apakah', 'arti', 'asap', 'asuransi', 'awet', 'bagaimana', 'bagus', 'bahan', 'baik', 'bakar', 'ban', 'bantuan', 'bearing', 'beberapa', 'bekerja', 'belakang', 'benar', 'bensin', 'berapa', 'berasap', 'berat', 'berbenturan', 'berbunyi', 'berfungsi', 'bergabung', 'bergetar', 'berisik', 'berjalan', 'berkala', 'berkali-kali', 'berkarat', 'berkedip', 'berkendara', 'berkualitas', 'berkurang', 'bermasalah', 'bertanda', 'biasa', 'bisa', 'bising', 'blong', 'bocor', 'bodynya', 'brebet', 'bunyi', 'bunyinya', 'buruk', 'busi', 'butuh', 'cable', 'cairan', 'cakram', 'campuran', 'cara', 'cat', 'cepat', 'cuaca', 'dalam', 'dan', 'dari', 'darurat', 'dashboard', 'dengan', 'depan', 'di', 'diam', 'dibawa', 'dibersihkan', 'diganti', 'digunakan', 'dihidupkan', 'dijatuhkan', 'diketahui', 'dikuatkan', 'dilakukan', 'dilumasi', 'dingin', 'dinyalakan', 'dipakai', 'diperhatikan', 'diperiksa', 'dipersiapkan', 'dipertimbangkan', 'diputar', 'dirawat', 'disiapkan', 'disimpan', 'efek', 'empty', 'filter', 'flash', 'fuel', 'ga', 'ganti', 'gejala', 'genggaman', 'getar', 'getaran', 'gigi', 'goyang', 'habis', 'hal', 'halo', 'handgrip', 'hari', 'harus', 'hello', 'hi', 'hilang', 'horn', 'hujan', 'idle', 'ikut', 'indikator', 'jadi', 'jadwal', 'jalan', 'jauh', 'jelek', 'jenis', 'jika', 'jok', 'kabel', 'kaca', 'kaki', 'kapan', 'karat', 'karburator', 'karena', 'kasar', 'kasih', 'keamanan', 'kebocoran', 'kecelakaan', 'kehilangan', 'kempes', 'kenapa', 'kencang', 'kera', 'keraguan', 'kerusakan', 'kesalahan', 'keselamatan', 'ketika', 'kit', 'klaim', 'klakson', 'klub', 'knalpot', 'komunitas', 'kondisi', 'kopling', 'kota', 'kotor', 'kualitas', 'kunci', 'laju', 'lakukan', 'lama', 'lambat', 'lampu', 'longgar', 'luar', 'makasih', 'maksud', 'malam', 'manfaat', 'masalah', 'masuk', 'mati', 'mau', 'melaju', 'melanjutkan', 'melumasi', 'memakai', 'membeli', 'membersihkan', 'membukanya', 'memeriksa', 'memilih', 'mempengaruhi', 'memutar', 'menampilkan', 'mendadak', 'menetes', 'mengajukan', 'mengapa', 'mengecek', 'mengeluarkan', 'mengendarai', 'mengetahui', 'mengganti', 'menggunakan', 'menghemat', 'menyala', 'menyesuaikan', 'menyimpan', 'merawat', 'meredam', 'merencanakan', 'merespons', 'mesin', 'minyak', 'mobil', 'mogok', 'mojok', 'motor', 'motorku', 'musim', 'ngadat', 'ngambek', 'normal', 'nyaman', 'oke', 'oli', 'onderdil', 'over', 'overheat', 'pada', 'pagi', 'panas', 'parkir', 'pecah', 'penanganan', 'pendingin', 'pengaruh', 'pengguna', 'penting', 'pentingnya', 'penyebab', 'penyok', 'perawatan', 'periksa', 'perjalanan', 'perlengkapan', 'perlu', 'perpindahan', 'persiapan', 'pertama', 'peyang', 'pindah', 'piston', 'pompa', 'pudar', 'putus', 'radio', 'rantai', 'rasa', 'recall', 'rem', 'rendah', 'retak', 'riding', 'rim', 'rusak', 'saat', 'saddle', 'saja', 'saya', 'sebelum', 'seberapa', 'seharusnya', 'sein', 'selamat', 'selip', 'sering', 'servis', 'setiap', 'siang', 'sistem', 'soak', 'sore', 'stabil', 'stand', 'start', 'suara', 'sudah', 'suka', 'sulit', 'susah', 'suspensi', 'tanda', 'tanda-tanda', 'tangan', 'tangki', 'tanpa', 'tekanan', 'tempatnya', 'tenaga', 'tentang', 'terasa', 'terbaik', 'terbaru', 'terdengar', 'terendam', 'terhadap', 'terima', 'terjadi', 'terjebak', 'terkena', 'terkunci', 'terlalu', 'terluka', 'thank', 'tidak', 'tip', 'touring', 'transmisi', 'tren', 'tumpah', 'umum', 'untuk', 'warning', 'yang', 'you']

# %%
# create our training data
training = []

# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
   
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

random.shuffle(training)
training = np.array(training, dtype=object)

# create train and test lists
train_x = list(training[:,0])
train_y = list(training[:,1])

print("Training data created")
# Out:
# Training data created

# %%
# Define NN model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model using legacy SGD
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Fit and save the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('models.h5')

print("\n")
print("*" * 50)
print("\nModel Created Successfully!")
# Out:
# Epoch 1/200
# 50/50 [==============================] - 1s 1ms/step - loss: 4.6416 - accuracy: 0.0080
# Epoch 2/200
# 50/50 [==============================] - 0s 1ms/step - loss: 4.6223 - accuracy: 0.0040
# Epoch 3/200
# 50/50 [==============================] - 0s 1ms/step - loss: 4.5977 - accuracy: 0.0280
# Epoch 4/200
# 50/50 [==============================] - 0s 2ms/step - loss: 4.5604 - accuracy: 0.0320
# Epoch 5/200
# 50/50 [==============================] - 0s 1ms/step - loss: 4.5327 - accuracy: 0.0360
# Epoch 6/200
# 50/50 [==============================] - 0s 2ms/step - loss: 4.5127 - accuracy: 0.0400
# Epoch 7/200
# 50/50 [==============================] - 0s 1ms/step - loss: 4.4745 - accuracy: 0.0480
# Epoch 8/200
# 50/50 [==============================] - 0s 1ms/step - loss: 4.4019 - accuracy: 0.0640
# Epoch 9/200
# 50/50 [==============================] - 0s 2ms/step - loss: 4.3143 - accuracy: 0.0760
# Epoch 10/200
# 50/50 [==============================] - 0s 2ms/step - loss: 4.3272 - accuracy: 0.0560
# Epoch 11/200
# 50/50 [==============================] - 0s 1ms/step - loss: 4.1540 - accuracy: 0.0760
# Epoch 12/200
# 50/50 [==============================] - 0s 1ms/step - loss: 4.0838 - accuracy: 0.1160
# Epoch 13/200
# 50/50 [==============================] - 0s 1ms/step - loss: 3.9715 - accuracy: 0.1200
# Epoch 14/200
# 50/50 [==============================] - 0s 1ms/step - loss: 3.7627 - accuracy: 0.1320
# Epoch 15/200
# 50/50 [==============================] - 0s 1ms/step - loss: 3.5754 - accuracy: 0.1560
# Epoch 16/200
# 50/50 [==============================] - 0s 1ms/step - loss: 3.5583 - accuracy: 0.1480
# Epoch 17/200
# 50/50 [==============================] - 0s 1ms/step - loss: 3.4426 - accuracy: 0.1720
# Epoch 18/200
# 50/50 [==============================] - 0s 1ms/step - loss: 3.3895 - accuracy: 0.1720
# Epoch 19/200
# 50/50 [==============================] - 0s 1ms/step - loss: 3.1767 - accuracy: 0.2080
# Epoch 20/200
# 50/50 [==============================] - 0s 2ms/step - loss: 3.0075 - accuracy: 0.2760
# Epoch 21/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.9612 - accuracy: 0.2760
# Epoch 22/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.7144 - accuracy: 0.3280
# Epoch 23/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.6703 - accuracy: 0.3160
# Epoch 24/200
# 50/50 [==============================] - 0s 1ms/step - loss: 2.6035 - accuracy: 0.3000
# Epoch 25/200
# 50/50 [==============================] - 0s 1ms/step - loss: 2.5481 - accuracy: 0.3360
# Epoch 26/200
# 50/50 [==============================] - 0s 1ms/step - loss: 2.3220 - accuracy: 0.3680
# Epoch 27/200
# 50/50 [==============================] - 0s 1ms/step - loss: 2.3449 - accuracy: 0.3000
# Epoch 28/200
# 50/50 [==============================] - 0s 1ms/step - loss: 2.1173 - accuracy: 0.4320
# Epoch 29/200
# 50/50 [==============================] - 0s 1ms/step - loss: 2.1941 - accuracy: 0.4200
# Epoch 30/200
# 50/50 [==============================] - 0s 1ms/step - loss: 2.0211 - accuracy: 0.4200
# Epoch 31/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.9155 - accuracy: 0.4920
# Epoch 32/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.9025 - accuracy: 0.4680
# Epoch 33/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.8827 - accuracy: 0.4720
# Epoch 34/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.7824 - accuracy: 0.5160
# Epoch 35/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.7226 - accuracy: 0.5040
# Epoch 36/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.5814 - accuracy: 0.5160
# Epoch 37/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.6664 - accuracy: 0.5040
# Epoch 38/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.5992 - accuracy: 0.5440
# Epoch 39/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.5868 - accuracy: 0.5080
# Epoch 40/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.4912 - accuracy: 0.5840
# Epoch 41/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.4127 - accuracy: 0.5920
# Epoch 42/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.4391 - accuracy: 0.6160
# Epoch 43/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.4663 - accuracy: 0.5560
# Epoch 44/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.4285 - accuracy: 0.5840
# Epoch 45/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.4263 - accuracy: 0.6160
# Epoch 46/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.3292 - accuracy: 0.6000
# Epoch 47/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.3933 - accuracy: 0.5440
# Epoch 48/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.1848 - accuracy: 0.6360
# Epoch 49/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.1145 - accuracy: 0.6560
# Epoch 50/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.2812 - accuracy: 0.6080
# Epoch 51/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.1639 - accuracy: 0.6600
# Epoch 52/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.2061 - accuracy: 0.6760
# Epoch 53/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.1616 - accuracy: 0.6280
# Epoch 54/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.2240 - accuracy: 0.6440
# Epoch 55/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.1597 - accuracy: 0.6720
# Epoch 56/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.0326 - accuracy: 0.6800
# Epoch 57/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9477 - accuracy: 0.7080
# Epoch 58/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.1309 - accuracy: 0.6640
# Epoch 59/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.2577 - accuracy: 0.6000
# Epoch 60/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.0923 - accuracy: 0.6360
# Epoch 61/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.0705 - accuracy: 0.6640
# Epoch 62/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.0841 - accuracy: 0.7040
# Epoch 63/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.0310 - accuracy: 0.6800
# Epoch 64/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9938 - accuracy: 0.7080
# Epoch 65/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9477 - accuracy: 0.7160
# Epoch 66/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9246 - accuracy: 0.7400
# Epoch 67/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.0345 - accuracy: 0.6640
# Epoch 68/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9796 - accuracy: 0.6880
# Epoch 69/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8961 - accuracy: 0.7440
# Epoch 70/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9178 - accuracy: 0.7120
# Epoch 71/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8904 - accuracy: 0.7120
# Epoch 72/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8886 - accuracy: 0.7200
# Epoch 73/200
# 50/50 [==============================] - 0s 1ms/step - loss: 1.0227 - accuracy: 0.6840
# Epoch 74/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9019 - accuracy: 0.7040
# Epoch 75/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6961 - accuracy: 0.8200
# Epoch 76/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9935 - accuracy: 0.7160
# Epoch 77/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8774 - accuracy: 0.7400
# Epoch 78/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9386 - accuracy: 0.7040
# Epoch 79/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8197 - accuracy: 0.7360
# Epoch 80/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8438 - accuracy: 0.7320
# Epoch 81/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7351 - accuracy: 0.8000
# Epoch 82/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9514 - accuracy: 0.7000
# Epoch 83/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8925 - accuracy: 0.7240
# Epoch 84/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8311 - accuracy: 0.7400
# Epoch 85/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9158 - accuracy: 0.7280
# Epoch 86/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7805 - accuracy: 0.7520
# Epoch 87/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9025 - accuracy: 0.6960
# Epoch 88/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9018 - accuracy: 0.7120
# Epoch 89/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8808 - accuracy: 0.7280
# Epoch 90/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7667 - accuracy: 0.7440
# Epoch 91/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7654 - accuracy: 0.7880
# Epoch 92/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7333 - accuracy: 0.7840
# Epoch 93/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7673 - accuracy: 0.7720
# Epoch 94/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6280 - accuracy: 0.8240
# Epoch 95/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6621 - accuracy: 0.7880
# Epoch 96/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7126 - accuracy: 0.7640
# Epoch 97/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8267 - accuracy: 0.7640
# Epoch 98/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6498 - accuracy: 0.7920
# Epoch 99/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9054 - accuracy: 0.7040
# Epoch 100/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7817 - accuracy: 0.7600
# Epoch 101/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7831 - accuracy: 0.7800
# Epoch 102/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6909 - accuracy: 0.7720
# Epoch 103/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6970 - accuracy: 0.7680
# Epoch 104/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7758 - accuracy: 0.7800
# Epoch 105/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9027 - accuracy: 0.7320
# Epoch 106/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7768 - accuracy: 0.7800
# Epoch 107/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8372 - accuracy: 0.7360
# Epoch 108/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.7800
# Epoch 109/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6274 - accuracy: 0.7840
# Epoch 110/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5991 - accuracy: 0.8160
# Epoch 111/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7876 - accuracy: 0.7400
# Epoch 112/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8915 - accuracy: 0.7240
# Epoch 113/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6805 - accuracy: 0.7760
# Epoch 114/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7548 - accuracy: 0.7680
# Epoch 115/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7787 - accuracy: 0.7440
# Epoch 116/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5488 - accuracy: 0.8280
# Epoch 117/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6660 - accuracy: 0.8040
# Epoch 118/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6593 - accuracy: 0.7800
# Epoch 119/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6655 - accuracy: 0.8080
# Epoch 120/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5871 - accuracy: 0.7960
# Epoch 121/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8397 - accuracy: 0.7520
# Epoch 122/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7170 - accuracy: 0.7680
# Epoch 123/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6694 - accuracy: 0.7880
# Epoch 124/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8068 - accuracy: 0.7440
# Epoch 125/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8539 - accuracy: 0.7600
# Epoch 126/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7239 - accuracy: 0.8000
# Epoch 127/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5292 - accuracy: 0.8080
# Epoch 128/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5310 - accuracy: 0.8000
# Epoch 129/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6022 - accuracy: 0.8120
# Epoch 130/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6688 - accuracy: 0.8000
# Epoch 131/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6229 - accuracy: 0.8200
# Epoch 132/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5956 - accuracy: 0.7840
# Epoch 133/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7064 - accuracy: 0.7840
# Epoch 134/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8234 - accuracy: 0.7240
# Epoch 135/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6721 - accuracy: 0.7720
# Epoch 136/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7365 - accuracy: 0.7800
# Epoch 137/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6620 - accuracy: 0.7840
# Epoch 138/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6497 - accuracy: 0.7880
# Epoch 139/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6372 - accuracy: 0.8160
# Epoch 140/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6802 - accuracy: 0.7920
# Epoch 141/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6806 - accuracy: 0.7800
# Epoch 142/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7088 - accuracy: 0.7640
# Epoch 143/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7543 - accuracy: 0.7600
# Epoch 144/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5823 - accuracy: 0.8360
# Epoch 145/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7775 - accuracy: 0.7520
# Epoch 146/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5971 - accuracy: 0.8080
# Epoch 147/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5164 - accuracy: 0.8040
# Epoch 148/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6274 - accuracy: 0.8120
# Epoch 149/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7810 - accuracy: 0.7680
# Epoch 150/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7057 - accuracy: 0.7840
# Epoch 151/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6467 - accuracy: 0.7960
# Epoch 152/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6630 - accuracy: 0.7840
# Epoch 153/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6046 - accuracy: 0.8160
# Epoch 154/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5617 - accuracy: 0.8160
# Epoch 155/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5310 - accuracy: 0.8400
# Epoch 156/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6829 - accuracy: 0.7920
# Epoch 157/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6780 - accuracy: 0.8240
# Epoch 158/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5623 - accuracy: 0.8200
# Epoch 159/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6750 - accuracy: 0.7920
# Epoch 160/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6541 - accuracy: 0.8240
# Epoch 161/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5993 - accuracy: 0.8240
# Epoch 162/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7933 - accuracy: 0.7800
# Epoch 163/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6947 - accuracy: 0.8080
# Epoch 164/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6117 - accuracy: 0.8200
# Epoch 165/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6413 - accuracy: 0.8320
# Epoch 166/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6507 - accuracy: 0.8120
# Epoch 167/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7209 - accuracy: 0.7880
# Epoch 168/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5884 - accuracy: 0.8240
# Epoch 169/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6096 - accuracy: 0.7800
# Epoch 170/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6479 - accuracy: 0.8280
# Epoch 171/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5787 - accuracy: 0.8160
# Epoch 172/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7071 - accuracy: 0.7360
# Epoch 173/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7906 - accuracy: 0.7520
# Epoch 174/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6837 - accuracy: 0.8160
# Epoch 175/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5755 - accuracy: 0.8320
# Epoch 176/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6686 - accuracy: 0.7960
# Epoch 177/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6148 - accuracy: 0.8040
# Epoch 178/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7069 - accuracy: 0.7880
# Epoch 179/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5456 - accuracy: 0.8400
# Epoch 180/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7556 - accuracy: 0.8080
# Epoch 181/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6244 - accuracy: 0.8240
# Epoch 182/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5597 - accuracy: 0.8360
# Epoch 183/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5347 - accuracy: 0.8360
# Epoch 184/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6435 - accuracy: 0.8320
# Epoch 185/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4903 - accuracy: 0.8360
# Epoch 186/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6144 - accuracy: 0.8280
# Epoch 187/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5555 - accuracy: 0.8400
# Epoch 188/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5422 - accuracy: 0.8520
# Epoch 189/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6734 - accuracy: 0.7880
# Epoch 190/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7497 - accuracy: 0.7320
# Epoch 191/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5757 - accuracy: 0.8120
# Epoch 192/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7229 - accuracy: 0.7520
# Epoch 193/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5940 - accuracy: 0.8240
# Epoch 194/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7605 - accuracy: 0.7840
# Epoch 195/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4884 - accuracy: 0.8520
# Epoch 196/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5714 - accuracy: 0.8560
# Epoch 197/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6006 - accuracy: 0.7760
# Epoch 198/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6957 - accuracy: 0.7880
# Epoch 199/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6869 - accuracy: 0.7840
# Epoch 200/200
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6438 - accuracy: 0.8240
#
#
# **************************************************
#
# Model Created Successfully!

# %%
loss, accuracy = model.evaluate(np.array(train_x), np.array(train_y), verbose=1)
print(f"Loss: {loss}, Accuracy: {accuracy}")
# Out:
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 0.9960
# Loss: 0.0189808402210474, Accuracy: 0.9959999918937683
